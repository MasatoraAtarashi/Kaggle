# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
combine = [train_df, test_df]

# %%
plt.scatter(train_df["YearBuilt"], train_df["SalePrice"])

# %%
plt.scatter(train_df["YearRemodAdd"], train_df["SalePrice"])

# %%
print(train_df[["YearRemodAdd", "YearBuilt"]].corr())
# Out:
#               YearRemodAdd  YearBuilt
# YearRemodAdd      1.000000   0.592855
# YearBuilt         0.592855   1.000000

# %%
plt.scatter(train_df["LotArea"], train_df["SalePrice"])

# %%
for dataset in combine:
    dataset['Quality'] = dataset['OverallQual'] * dataset['OverallCond']

plt.scatter(train_df["Quality"], train_df["SalePrice"])

# %%
train_df['Quality_band'] = pd.cut(train_df['Quality'], 5)
train_df[['Quality_band', 'SalePrice']].groupby(['Quality_band'], as_index=False).mean().sort_values(by='Quality_band', ascending=True)
# Out:
#     Quality_band      SalePrice
# 0  (0.911, 18.8]   98205.593750
# 1   (18.8, 36.6]  157973.754386
# 2   (36.6, 54.4]  243935.367089
# 3   (54.4, 72.2]  254291.666667
# 4   (72.2, 90.0]  400000.000000

# %%
for dataset in combine:
    dataset.loc[ dataset['Quality'] <= 18.8, 'Quality'] = 0
    dataset.loc[(dataset['Quality'] > 18.8) & (dataset['Quality'] <= 36.6), 'Quality'] = 1
    dataset.loc[(dataset['Quality'] > 36.6) & (dataset['Quality'] <= 54.4), 'Quality'] = 2
    dataset.loc[(dataset['Quality'] > 54.4) & (dataset['Quality'] <= 72.2), 'Quality'] = 3
    dataset.loc[ dataset['Quality'] >72.2, 'Quality'] = 4

train_df = train_df.drop(['Quality_band'], axis=1)
combine = [train_df, test_df]
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolQC Fence MiscFeature MiscVal MoSold YrSold  \
# 0         Lvl    AllPub  ...    NaN   NaN         NaN       0      2   2008
# 1         Lvl    AllPub  ...    NaN   NaN         NaN       0      5   2007
# 2         Lvl    AllPub  ...    NaN   NaN         NaN       0      9   2008
# 3         Lvl    AllPub  ...    NaN   NaN         NaN       0      2   2006
# 4         Lvl    AllPub  ...    NaN   NaN         NaN       0     12   2008
#
#   SaleType  SaleCondition  SalePrice  Quality
# ...

# %%
plt.scatter(train_df["Quality"], train_df["SalePrice"])

# %%
plt.scatter(train_df["KitchenQual"], train_df["SalePrice"])

# %%
train_df[['Street', 'SalePrice']].groupby(['Street'], as_index=False).mean().sort_values(by='SalePrice', ascending=False)
# Out:
#   Street      SalePrice
# 1   Pave  181130.538514
# 0   Grvl  130190.500000

# %%
train_df[['Alley', 'SalePrice']].groupby(['Alley'], as_index=False).mean().sort_values(by='SalePrice', ascending=False)
# Out:
#   Alley      SalePrice
# 1  Pave  168000.585366
# 0  Grvl  122219.080000

# %%
plt.scatter(train_df["YrSold"], train_df["SalePrice"])

# %%
plt.scatter(train_df["MoSold"], train_df["SalePrice"])

# %%
plt.scatter(train_df["MSZoning"], train_df["SalePrice"])

# %%
plt.scatter(train_df["Neighborhood"], train_df["SalePrice"])

# %%
for dataset in combine:
    dataset['new'] = (2019 - dataset['YearRemodAdd']) + (2019 - dataset['YearBuilt'])

plt.scatter(train_df["new"], train_df["SalePrice"])

# %%
train_df['new_band'] = pd.cut(train_df['new'], 5)
train_df[['new_band', 'SalePrice']].groupby(['new_band'], as_index=False).mean().sort_values(by='new_band', ascending=True)
# Out:
#          new_band      SalePrice
# 0   (17.81, 56.0]  237547.910747
# 1    (56.0, 94.0]  168274.320872
# 2   (94.0, 132.0]  142583.625344
# 3  (132.0, 170.0]  125091.158163
# 4  (170.0, 208.0]  110947.193548

# %%
for dataset in combine:
    dataset.loc[ dataset['new'] <= 56, 'new'] = 0
    dataset.loc[(dataset['new'] > 56) & (dataset['new'] <= 94), 'new'] = 1
    dataset.loc[(dataset['new'] > 94) & (dataset['new'] <= 132), 'new'] = 2
    dataset.loc[(dataset['new'] > 132) & (dataset['new'] <= 170), 'new'] = 3
    dataset.loc[ dataset['new'] >170, 'new'] = 4

train_df = train_df.drop(['new_band'], axis=1)
combine = [train_df, test_df]
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... Fence MiscFeature MiscVal MoSold YrSold SaleType  \
# 0         Lvl    AllPub  ...   NaN         NaN       0      2   2008       WD
# 1         Lvl    AllPub  ...   NaN         NaN       0      5   2007       WD
# 2         Lvl    AllPub  ...   NaN         NaN       0      9   2008       WD
# 3         Lvl    AllPub  ...   NaN         NaN       0      2   2006       WD
# 4         Lvl    AllPub  ...   NaN         NaN       0     12   2008       WD
#
#   SaleCondition  SalePrice  Quality  new
# ...

# %%
plt.scatter(train_df["new"], train_df["SalePrice"])

# %%
train_df[['new', 'SalePrice']].groupby(['new'], as_index=False).mean().sort_values(by='SalePrice', ascending=False)
# Out:
#    new      SalePrice
# 0    0  237547.910747
# 1    1  168274.320872
# 2    2  142583.625344
# 3    3  125091.158163
# 4    4  110947.193548

# %%
train_df[['Alley', 'SalePrice']].groupby(['Alley'], as_index=False).mean().sort_values(by='SalePrice', ascending=False)
# Out:
#   Alley      SalePrice
# 1  Pave  168000.585366
# 0  Grvl  122219.080000

# %%
pd.crosstab(train_df['Alley'], train_df['Street'])
# Out:
# Street  Pave
# Alley
# Grvl      50
# Pave      41

# %%
freq_Street = train_df.Street.dropna().mode()[0]
train_df.Street.value_counts()
# Out:
# Pave    1454
# Grvl       6
# Name: Street, dtype: int64

# %%
train_df['Alley'].fillna('Na', inplace=True)
test_df['Alley'].fillna('Na', inplace=True)
for dataset in combine:
    dataset['Alley'] = dataset['Alley'].map({'Grvl': 0, 'Pave': 1, 'Na': 2})

for dataset in combine:
    dataset['IsAlley'] = 0
    dataset.loc[dataset['Alley'] == 1, 'IsAlley'] = 1
    dataset.loc[dataset['Alley'] == 0, 'IsAlley'] = 1

# %%
# train_df[['IsAlley', 'SalePrice']].groupby(['IsAlley'], as_index=False).mean()
train_df[['Alley', 'SalePrice']].groupby(['Alley'], as_index=False).mean()
# print(train_df['Alley'].tail(20))
# print(train_df['IsAlley'].tail(20))
# Out:
#    Alley      SalePrice
# 0      0  122219.080000
# 1      1  168000.585366
# 2      2  183452.131483

# %%
plt.scatter(train_df["WoodDeckSF"], train_df["SalePrice"])

# %%
for dataset in combine:
    dataset['IsWoodDeckSF'] = 1
    dataset.loc[dataset['WoodDeckSF'] == 0, 'IsWoodDeckSF'] = 0

train_df[['IsWoodDeckSF', 'SalePrice']].groupby(['IsWoodDeckSF'], as_index=False).mean()
# Out:
#    IsWoodDeckSF      SalePrice
# 0             0  158265.695138
# 1             1  205586.197425

# %%
for dataset in combine:
    dataset['Porch'] = dataset['OpenPorchSF'] + dataset['EnclosedPorch'] + dataset['Porch'] + dataset['Porch'] + dataset['Porch']
